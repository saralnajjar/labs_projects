# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# ## Exercise - Exploratory Data Analysis using `pandas`

# %%
import pandas as pd

# %% [markdown]
# ### A. Explore _Mad Men_ Cast Data
#
# ---
#
# #### 1. Load the _Mad Men_ cast data into a `pandas` DataFrame.

# %%
cast = pd.read_csv('./data/mad-men-cast-show-data.csv', encoding='latin-1')

# %% [markdown]
# - Note: the dataset is opened with encoding='laten-1' because it contains special characters that break the default UTF-8 decoder
# - Specifically, the dataset contains some performers names with special characters like Alexander Skarsgård

# %% [markdown]
# #### 2. Display the head and tail of the data.

# %%
# display the head of the data
# Your code here please
cast.head()
# Out:
#           Performer          Show  Show Start Show End Status?  CharEnd  \
# 0       Steven Hill   Law & Order        1990     2010     END     2000
# 1    Kelli Williams  The Practice        1997     2014     END     2003
# 2  LisaGay Hamilton  The Practice        1997     2014     END     2003
# 3  Lara Flynn Boyle  The Practice        1997     2014     END     2003
# 4   Dylan McDermott  The Practice        1997     2014     END     2004
#
#    Years Since  #LEAD  #SUPPORT  #Shows  Score      Score/Y  \
# 0           15      0         0       0   0.00            0
# 1           12      0         1       6   6.25  0.520833333
# 2           12      2         0       2   4.00  0.333333333
# 3           12      0         0       0   0.00            0
# 4           11      2         7       6   9.75  0.886363636
#
#                                    lead_notes  \
# 0                                         NaN
# 1                                         NaN
# ...

# %%
# NO CODE HERE PLEASE
# Out:
#           Performer          Show  Show Start Show End Status?  CharEnd  \
# 0       Steven Hill   Law & Order        1990     2010     END     2000
# 1    Kelli Williams  The Practice        1997     2014     END     2003
# 2  LisaGay Hamilton  The Practice        1997     2014     END     2003
# 3  Lara Flynn Boyle  The Practice        1997     2014     END     2003
# 4   Dylan McDermott  The Practice        1997     2014     END     2004
#
#    Years Since  #LEAD  #SUPPORT  #Shows  Score      Score/Y  \
# 0           15      0         0       0   0.00            0
# 1           12      0         1       6   6.25  0.520833333
# 2           12      2         0       2   4.00  0.333333333
# 3           12      0         0       0   0.00            0
# 4           11      2         7       6   9.75  0.886363636
#
#                                    lead_notes  \
# 0                                         NaN
# 1                                         NaN
# ...

# %%
# display the tail of the data
# Your code here please
cast.tail()
# Out:
#            Performer             Show  Show Start Show End Status?  CharEnd  \
# 243     Meghan Wolfe   True Detective        2014  PRESENT    LEFT     2014
# 244       Kevin Dunn   True Detective        2014  PRESENT    LEFT     2014
# 245    Charles Dance  Game of Thrones        2011  PRESENT    LEFT     2015
# 246  Patrick Dempsey   Grey's Anatomy        2005  PRESENT    LEFT     2015
# 247   Ian McElhinney  Game of Thrones        2011  PRESENT    LEFT     2015
#
#      Years Since  #LEAD  #SUPPORT  #Shows  Score  Score/Y lead_notes  \
# 243            1      0         0       0   0.00        0        NaN
# 244            1      0         1       2   2.25     2.25        NaN
# 245            0      0         2       1   1.50  #DIV/0!        NaN
# 246            0      0         0       0   0.00  #DIV/0!        NaN
# 247            0      0         0       0   0.00  #DIV/0!        NaN
#
#                            support_notes                    show_notes
# ...

# %%
# NO CODE HERE PLEASE
# Out:
#            Performer             Show  Show Start Show End Status?  CharEnd  \
# 243     Meghan Wolfe   True Detective        2014  PRESENT    LEFT     2014
# 244       Kevin Dunn   True Detective        2014  PRESENT    LEFT     2014
# 245    Charles Dance  Game of Thrones        2011  PRESENT    LEFT     2015
# 246  Patrick Dempsey   Grey's Anatomy        2005  PRESENT    LEFT     2015
# 247   Ian McElhinney  Game of Thrones        2011  PRESENT    LEFT     2015
#
#      Years Since  #LEAD  #SUPPORT  #Shows  Score  Score/Y lead_notes  \
# 243            1      0         0       0   0.00        0        NaN
# 244            1      0         1       2   2.25     2.25        NaN
# 245            0      0         2       1   1.50  #DIV/0!        NaN
# 246            0      0         0       0   0.00  #DIV/0!        NaN
# 247            0      0         0       0   0.00  #DIV/0!        NaN
#
#                            support_notes                    show_notes
# ...

# %% [markdown]
# #### 3. Print the columns of the data.

# %%
# Your code here please
cast.columns
# Out:
# Index(['Performer', 'Show', 'Show Start', 'Show End', 'Status?', 'CharEnd',
#        'Years Since', '#LEAD', '#SUPPORT', '#Shows', 'Score', 'Score/Y',
#        'lead_notes', 'support_notes', 'show_notes'],
#       dtype='str')

# %%
# NO CODE HERE PLEASE
# Out:
# Index(['Performer', 'Show', 'Show Start', 'Show End', 'Status?', 'CharEnd',
#        'Years Since', '#LEAD', '#SUPPORT', '#Shows', 'Score', 'Score/Y',
#        'lead_notes', 'support_notes', 'show_notes'],
#       dtype='object')

# %% [markdown]
# #### 4. Rename any columns with spaces or special characters to not contain any.

# %%
# Your code here please
cast.rename(columns={
        'Show Start':'ShowStart',
        'Show End':'ShowEnd',
        'Status?':'Status',
        'Years Since':'YearsSince',
        '#LEAD':'LEAD',
        '#SUPPORT' : 'SUPPORT',
        '#Shows' : 'Shows',
        'Score/Y' : 'ScoreY',
        'lead_notes' : 'leadnotes',
        'support_notes' : 'supportnotes',
        'show_notes' : 'shownotes',

    }, inplace=True)
       

# finally print cast columns to confirm if your code was OK or not
print(cast.columns)
# Out:
# Index(['Performer', 'Show', 'ShowStart', 'ShowEnd', 'Status', 'CharEnd',
#        'YearsSince', 'LEAD', 'SUPPORT', 'Shows', 'Score', 'ScoreY',
#        'leadnotes', 'supportnotes', 'shownotes'],
#       dtype='str')

# %%
# NO CODE HERE PLEASE
# Out:
# Index(['Performer', 'Show', 'ShowStart', 'ShowEnd', 'Status', 'CharEnd',
#        'YearsSince', 'LEAD', 'SUPPORT', 'Shows', 'Score', 'ScoreY',
#        'leadnotes', 'supportnotes', 'shownotes'],
#       dtype='object')

# %% [markdown]
# #### 5. Filter the data where the status of the show is not "END" or "End."

# %%
# Your code here please
cast[
    (cast['Status'] != 'END')
    &
    (cast['Status'] != 'End')
]
# Out:
#                Performer                             Show  ShowStart  ShowEnd  \
# 157     Siobhan Finneran                    Downton Abbey       2010  PRESENT
# 162            Eric Dane                   Grey's Anatomy       2005  PRESENT
# 163       David Harewood                         Homeland       2011  PRESENT
# 171          Dan Stevens                    Downton Abbey       2010  PRESENT
# 173     Michelle Fairley                  Game of Thrones       2011  PRESENT
# 177      Morena Baccarin                         Homeland       2011  PRESENT
# 178    Diego Klattenhoff                         Homeland       2011  PRESENT
# 179    Marg Helgenberger  CSI: Crime Scene Investigations       2000  PRESENT
# 200         Jackson Pace                         Homeland       2011  PRESENT
# 201        Morgan Saylor                         Homeland       2011  PRESENT
# 205          Rory McCann                  Game of Thrones       2011  PRESENT
# ...

# %%
# NO CODE HERE PLEASE
# Out:
#                Performer                             Show  ShowStart  ShowEnd  \
# 157     Siobhan Finneran                    Downton Abbey       2010  PRESENT
# 162            Eric Dane                   Grey's Anatomy       2005  PRESENT
# 163       David Harewood                         Homeland       2011  PRESENT
# 171          Dan Stevens                    Downton Abbey       2010  PRESENT
# 173     Michelle Fairley                  Game of Thrones       2011  PRESENT
# 177      Morena Baccarin                         Homeland       2011  PRESENT
# 178    Diego Klattenhoff                         Homeland       2011  PRESENT
# 179    Marg Helgenberger  CSI: Crime Scene Investigations       2000  PRESENT
# 200         Jackson Pace                         Homeland       2011  PRESENT
# 201        Morgan Saylor                         Homeland       2011  PRESENT
# 205          Rory McCann                  Game of Thrones       2011  PRESENT
# ...

# %% [markdown]
# #### 6. Print out the performers where the show start is greater than 2005 and the score is greater than 7.

# %%
# Your code here please
cast[
    (cast['ShowStart'] > 2005)
    &
    (cast['Score'] > 7)
]
# Out:
#             Performer                 Show  ShowStart  ShowEnd Status  \
# 95       Scott Porter  Friday Night Lights       2006     2011    END
# 132    Connie Britton  Friday Night Lights       2006     2011    END
# 149   Amanda Seyfried             Big Love       2006     2011    End
# 157  Siobhan Finneran        Downton Abbey       2010  PRESENT   LEFT
#
#      CharEnd  YearsSince  LEAD  SUPPORT  Shows  Score       ScoreY  \
# 95      2010           5     3        1      6   9.25         1.85
# 132     2011           4     3        1      4   7.25       1.8125
# 149     2011           4     8        3      0   8.75       2.1875
# 157     2012           3     0        0      8   8.00  2.666666667
#
#                                              leadnotes  \
# 95   The Good Guy, 2010; 10 Years, 2012; The To Do ...
# 132  The Fitzgerald Family Christmas, 2012; Angels ...
# 149  Red Riding Hood, 2011; In Time, 2011; Gine, 20...
# ...

# %%
# NO CODE HERE PLEASE
# Out:
#             Performer                 Show  ShowStart  ShowEnd Status  \
# 95       Scott Porter  Friday Night Lights       2006     2011    END
# 132    Connie Britton  Friday Night Lights       2006     2011    END
# 149   Amanda Seyfried             Big Love       2006     2011    End
# 157  Siobhan Finneran        Downton Abbey       2010  PRESENT   LEFT
#
#      CharEnd  YearsSince  LEAD  SUPPORT  Shows  Score       ScoreY  \
# 95      2010           5     3        1      6   9.25         1.85
# 132     2011           4     3        1      4   7.25       1.8125
# 149     2011           4     8        3      0   8.75       2.1875
# 157     2012           3     0        0      8   8.00  2.666666667
#
#                                              leadnotes  \
# 95   The Good Guy, 2010; 10 Years, 2012; The To Do ...
# 132  The Fitzgerald Family Christmas, 2012; Angels ...
# 149  Red Riding Hood, 2011; In Time, 2011; Gine, 20...
# ...

# %% [markdown]
# #### 7. show all the shows where the performer name ends with "son"

# %%
# Your code here please
cast[
    cast['Performer'].str.endswith('son')
]
# Out:
#                Performer             Show  ShowStart  ShowEnd Status  CharEnd  \
# 35       Paula Malcomson         Deadwood       2004     2006    END     2006
# 40     William Sanderson         Deadwood       2004     2006    END     2006
# 55       NiCole Robinson    The West Wing       1999     2006    END     2006
# 59           Peter Jason         Deadwood       2004     2006    END     2006
# 62        Ralph Richeson         Deadwood       2004     2006    END     2006
# 98       Michael Emerson             Lost       2004     2010    END     2010
# 122  S. Epatha Merkerson      Law & Order       1990     2010    END     2010
# 125          James Kyson           Heroes       2006     2010    END     2010
# 158    Jennifer Morrison            House       2004     2012    END     2012
# 166       Peter Jacobson            House       2004     2012    END     2012
# 170   Christina Robinson           Dexter       2006     2013    END     2012
# ...

# %%
# NO CODE HERE PLEASE
# Out:
#                Performer             Show  ShowStart  ShowEnd Status  CharEnd  \
# 35       Paula Malcomson         Deadwood       2004     2006    END     2006
# 40     William Sanderson         Deadwood       2004     2006    END     2006
# 55       NiCole Robinson    The West Wing       1999     2006    END     2006
# 59           Peter Jason         Deadwood       2004     2006    END     2006
# 62        Ralph Richeson         Deadwood       2004     2006    END     2006
# 98       Michael Emerson             Lost       2004     2010    END     2010
# 122  S. Epatha Merkerson      Law & Order       1990     2010    END     2010
# 125          James Kyson           Heroes       2006     2010    END     2010
# 158    Jennifer Morrison            House       2004     2012    END     2012
# 166       Peter Jacobson            House       2004     2012    END     2012
# 170   Christina Robinson           Dexter       2006     2013    END     2012
# ...

# %% [markdown]
# #### 8. show all the shows where the performer name ends with "son" and the column "shownotes" is empty

# %%
# Your code here please
cast[
    (cast['Performer'].str.endswith('son'))
    &
    (cast['shownotes'].isnull())
]
# Out:
#                Performer             Show  ShowStart  ShowEnd Status  CharEnd  \
# 55       NiCole Robinson    The West Wing       1999     2006    END     2006
# 59           Peter Jason         Deadwood       2004     2006    END     2006
# 62        Ralph Richeson         Deadwood       2004     2006    END     2006
# 122  S. Epatha Merkerson      Law & Order       1990     2010    END     2010
# 125          James Kyson           Heroes       2006     2010    END     2010
# 166       Peter Jacobson            House       2004     2012    END     2012
# 170   Christina Robinson           Dexter       2006     2013    END     2012
# 231         Jack Gleeson  Game of Thrones       2011  PRESENT   LEFT     2014
# 234      Woody Harrelson   True Detective       2014  PRESENT   LEFT     2014
#
#      YearsSince  LEAD  SUPPORT  Shows  Score       ScoreY      leadnotes  \
# 55            9     0        0      0   0.00            0            NaN
# ...

# %%
# NO CODE HERE PLEASE
# Out:
#                Performer             Show  ShowStart  ShowEnd Status  CharEnd  \
# 55       NiCole Robinson    The West Wing       1999     2006    END     2006
# 59           Peter Jason         Deadwood       2004     2006    END     2006
# 62        Ralph Richeson         Deadwood       2004     2006    END     2006
# 122  S. Epatha Merkerson      Law & Order       1990     2010    END     2010
# 125          James Kyson           Heroes       2006     2010    END     2010
# 166       Peter Jacobson            House       2004     2012    END     2012
# 170   Christina Robinson           Dexter       2006     2013    END     2012
# 231         Jack Gleeson  Game of Thrones       2011  PRESENT   LEFT     2014
# 234      Woody Harrelson   True Detective       2014  PRESENT   LEFT     2014
#
#      YearsSince  LEAD  SUPPORT  Shows  Score       ScoreY      leadnotes  \
# 55            9     0        0      0   0.00            0            NaN
# ...

# %% [markdown]
# ##### 9. Select the `performer` and `show` columns for the 20th-24th rows.

# %%
# Your code here please
# Hint: use iloc or direct slicer (check the lecture file)
# or you can use `loc`, search in the internet to get more about loc
cast.iloc[20:25][['Performer', 'Show']]
# Out:
#              Performer             Show
# 20    Mary Steenburgen  Joan of Arcadia
# 21  Mathew St. Patrick   Six Feet Under
# 22       Michael Welch  Joan of Arcadia
# 23    Aaron Himelstein  Joan of Arcadia
# 24     Becky Wahlstrom  Joan of Arcadia

# %%
# NO CODE HERE PLEASE
# Out:
#              Performer             Show
# 20    Mary Steenburgen  Joan of Arcadia
# 21  Mathew St. Patrick   Six Feet Under
# 22       Michael Welch  Joan of Arcadia
# 23    Aaron Himelstein  Joan of Arcadia
# 24     Becky Wahlstrom  Joan of Arcadia

# %% [markdown]
# #### 10. Plot a histogram of score.

# %%
# Your code here please

# Hint: Use .hist
# Don't show the grid
cast.hist('Score', grid=False)
# Out:
# array([[<Axes: title={'center': 'Score'}>]], dtype=object)

# %%
# NO CODE HERE PLEASE

# %% [markdown]
# ### B. Explore San Francisco Crime Data
#
# ---
#
# #### B.1 Load the San Francisco crime data set into a DataFrame and display the head.

# %%
crime_csv = 'sf_crime.csv'

# %%
# Your code here please
crime = pd.read_csv('./data/sf_crime.csv')
crime
# Out:
#                      Dates        Category                           Descript  \
# 0      2003-03-23 23:27:00           ARSON                 ARSON OF A VEHICLE
# 1      2006-03-07 06:45:00   LARCENY/THEFT       PETTY THEFT FROM LOCKED AUTO
# 2      2004-03-06 03:00:00    NON-CRIMINAL                      LOST PROPERTY
# 3      2011-12-03 12:10:00        BURGLARY  BURGLARY OF STORE, UNLAWFUL ENTRY
# 4      2003-01-10 00:15:00   LARCENY/THEFT            PETTY THEFT OF PROPERTY
# ...                    ...             ...                                ...
# 24995  2005-05-04 22:30:00   VEHICLE THEFT           VEHICLE, RECOVERED, AUTO
# 24996  2014-09-29 15:00:00   LARCENY/THEFT       GRAND THEFT FROM LOCKED AUTO
# 24997  2008-04-01 13:54:00   DRUG/NARCOTIC     POSSESSION OF METH-AMPHETAMINE
# 24998  2011-01-11 07:21:00  OTHER OFFENSES                  TRAFFIC VIOLATION
# 24999  2013-04-30 15:07:00  SUSPICIOUS OCC              SUSPICIOUS OCCURRENCE
#
# ...

# %%
# NO CODE HERE PLEASE

# %% [markdown]
# #### B.2 Look at the dimensions of the crime data.

# %%
# Your code here please
crime.shape
# Out:
# (25000, 9)

# %%
# NO CODE HERE PLEASE

# %% [markdown]
# #### B.3 Look at the data types of the columns and print out the column names.

# %%
# Your code here please
crime.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Dates       25000 non-null  str
#  1   Category    25000 non-null  str
#  2   Descript    25000 non-null  str
#  3   DayOfWeek   25000 non-null  str
#  4   PdDistrict  25000 non-null  str
#  5   Resolution  25000 non-null  str
#  6   Address     25000 non-null  str
#  7   X           25000 non-null  float64
#  8   Y           25000 non-null  float64
# dtypes: float64(2), str(7)
# memory usage: 1.7 MB

# %%
# NO CODE HERE PLEASE
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 9 columns):
# Dates         25000 non-null object
# Category      25000 non-null object
# Descript      25000 non-null object
# DayOfWeek     25000 non-null object
# PdDistrict    25000 non-null object
# Resolution    25000 non-null object
# Address       25000 non-null object
# X             25000 non-null float64
# Y             25000 non-null float64
# dtypes: float64(2), object(7)
# memory usage: 1.7+ MB

# %%
# print the column names
# Your code here please
crime.columns
# Out:
# Index(['Dates', 'Category', 'Descript', 'DayOfWeek', 'PdDistrict',
#        'Resolution', 'Address', 'X', 'Y'],
#       dtype='str')

# %%
# NO CODE HERE PLEASE
# Out:
# Index(['Dates', 'Category', 'Descript', 'DayOfWeek', 'PdDistrict',
#        'Resolution', 'Address', 'X', 'Y'],
#       dtype='object')

# %% [markdown]
# #### B.4 How many distinct districts are there?

# %%
# Your code here please
crime[['PdDistrict']].describe()
# Hint: you can use either describe() and see the `unique` value or use nunique() functions
# Out:
#        PdDistrict
# count       25000
# unique         10
# top      SOUTHERN
# freq         4413

# %%
# NO CODE HERE PLEASE
# Out:
#        PdDistrict
# count       25000
# unique         10
# top      SOUTHERN
# freq         4413

# %% [markdown]
# #### B.5 Which day of the week has the most crime?
# - Hint: Category should not include `NON-CRIMINAL` as this is not a crime

# %%
# Your code here please
# Hint: after filtering and selecting the proper column, you can use describe()
# or use value_counts() and take the highest value
no_noncrim = crime[crime['Category'] != 'NON-CRIMINAL']
no_noncrim[['DayOfWeek']].describe()
# Out:
#        DayOfWeek
# count      22399
# unique         7
# top       Friday
# freq        3465

# %%
# NO CODE HERE PLEASE
# Out:
#        DayOfWeek
# count      22399
# unique         7
# top       Friday
# freq        3465

# %%
# Friday has the most crime.

# %% [markdown]
# #### B.6 Make a new DataFrame featuring the crime categories and the number of crimes per category.

# %%
# Your code here please

# Hint1: You can use the `.value_counts()` function, if you want
# Hint2: press the 'Tab' after your write `value_counts().` to show you possible functions to use... 
# One of them is used to convert to a dataframe.
crime['Category'].value_counts().to_frame()
# Out:
#                              count
# Category
# LARCENY/THEFT                 4934
# OTHER OFFENSES                3656
# NON-CRIMINAL                  2601
# ASSAULT                       2164
# DRUG/NARCOTIC                 1533
# VEHICLE THEFT                 1506
# VANDALISM                     1280
# WARRANTS                      1239
# BURGLARY                      1023
# SUSPICIOUS OCC                 891
# MISSING PERSON                 771
# ROBBERY                        630
# FRAUD                          537
# SECONDARY CODES                283
# FORGERY/COUNTERFEITING         281
# WEAPON LAWS                    255
# PROSTITUTION                   223
# TRESPASS                       209
# STOLEN PROPERTY                137
# SEX OFFENSES FORCIBLE          120
# DISORDERLY CONDUCT             105
# DRUNKENNESS                    105
# RECOVERED VEHICLE               80
# DRIVING UNDER THE INFLUENCE     75
# KIDNAPPING                      71
# ...

# %%
# NO CODE HERE PLEASE
# Out:
#                              count
# Category
# LARCENY/THEFT                 4934
# OTHER OFFENSES                3656
# NON-CRIMINAL                  2601
# ASSAULT                       2164
# DRUG/NARCOTIC                 1533
# VEHICLE THEFT                 1506
# VANDALISM                     1280
# WARRANTS                      1239
# BURGLARY                      1023
# SUSPICIOUS OCC                 891
# MISSING PERSON                 771
# ROBBERY                        630
# FRAUD                          537
# SECONDARY CODES                283
# FORGERY/COUNTERFEITING         281
# WEAPON LAWS                    255
# PROSTITUTION                   223
# TRESPASS                       209
# STOLEN PROPERTY                137
# SEX OFFENSES FORCIBLE          120
# DISORDERLY CONDUCT             105
# DRUNKENNESS                    105
# RECOVERED VEHICLE               80
# DRIVING UNDER THE INFLUENCE     75
# KIDNAPPING                      71
# ...

# %% [markdown]
# #### B.7 Make a DataFrame that includes the districts and crime counts per district. Which district has the most crime?
#
# - Hint: Category should not include `NON-CRIMINAL` as this is not a crime
#
# - Hint: You can use the `.sort_values()` function to sort your DataFrame by column.*

# %%
# Your code here please
no_noncrim['PdDistrict'].value_counts().to_frame()
# Out:
#             count
# PdDistrict
# SOUTHERN     3895
# MISSION      3066
# NORTHERN     2756
# BAYVIEW      2372
# TENDERLOIN   2134
# CENTRAL      2098
# INGLESIDE    2055
# TARAVAL      1608
# PARK         1283
# RICHMOND     1132

# %%
# NO CODE HERE PLEASE
# Out:
#             count
# PdDistrict
# SOUTHERN     3895
# MISSION      3066
# NORTHERN     2756
# BAYVIEW      2372
# TENDERLOIN   2134
# CENTRAL      2098
# INGLESIDE    2055
# TARAVAL      1608
# PARK         1283
# RICHMOND     1132

# %%
# SOUTHERN DISTRICT HAS THE HIGHER CRIMES

# %% [markdown]
# #### B.8 Show the crimes where the description of the crime has the word "vehicle"

# %%
# Your code here please
crime[
    crime['Descript'].str.contains('vehicle', case=False, na=False)
]
# Out:
#                      Dates        Category  \
# 0      2003-03-23 23:27:00           ARSON
# 6      2008-02-24 22:00:00   VEHICLE THEFT
# 19     2013-03-08 08:00:00  OTHER OFFENSES
# 27     2006-08-26 22:00:00       VANDALISM
# 34     2013-07-25 15:00:00       VANDALISM
# ...                    ...             ...
# 24910  2004-10-13 21:00:00   LARCENY/THEFT
# 24924  2004-10-03 17:30:00       VANDALISM
# 24927  2008-02-22 17:00:00       VANDALISM
# 24985  2004-03-06 20:30:00       VANDALISM
# 24995  2005-05-04 22:30:00   VEHICLE THEFT
#
#                                         Descript  DayOfWeek PdDistrict  \
# 0                             ARSON OF A VEHICLE     Sunday    BAYVIEW
# 6                   STOLEN AND RECOVERED VEHICLE     Sunday  INGLESIDE
# 19                      TAMPERING WITH A VEHICLE     Friday   NORTHERN
# 27     MALICIOUS MISCHIEF, VANDALISM OF VEHICLES   Saturday    BAYVIEW
# 34     MALICIOUS MISCHIEF, VANDALISM OF VEHICLES   Thursday    CENTRAL
# ...

# %%
# NO CODE HERE PLEASE
# Out:
#                      Dates        Category  \
# 0      2003-03-23 23:27:00           ARSON
# 6      2008-02-24 22:00:00   VEHICLE THEFT
# 19     2013-03-08 08:00:00  OTHER OFFENSES
# 27     2006-08-26 22:00:00       VANDALISM
# 34     2013-07-25 15:00:00       VANDALISM
# ...                    ...             ...
# 24910  2004-10-13 21:00:00   LARCENY/THEFT
# 24924  2004-10-03 17:30:00       VANDALISM
# 24927  2008-02-22 17:00:00       VANDALISM
# 24985  2004-03-06 20:30:00       VANDALISM
# 24995  2005-05-04 22:30:00   VEHICLE THEFT
#
#                                         Descript  DayOfWeek PdDistrict  \
# 0                             ARSON OF A VEHICLE     Sunday    BAYVIEW
# 6                   STOLEN AND RECOVERED VEHICLE     Sunday  INGLESIDE
# 19                      TAMPERING WITH A VEHICLE     Friday   NORTHERN
# 27     MALICIOUS MISCHIEF, VANDALISM OF VEHICLES   Saturday    BAYVIEW
# 34     MALICIOUS MISCHIEF, VANDALISM OF VEHICLES   Thursday    CENTRAL
# ...

# %% [markdown]
# #### B.9 Show the crimes where the description of the crime has the word "vehicle" or the word "property"

# %%
# Your code here please
crime[
    (crime['Descript'].str.contains('vehicle', case=False, na=False))
    |
    (crime['Descript'].str.contains('property', case=False, na=False))
]
# Out:
#                      Dates        Category  \
# 0      2003-03-23 23:27:00           ARSON
# 2      2004-03-06 03:00:00    NON-CRIMINAL
# 4      2003-01-10 00:15:00   LARCENY/THEFT
# 6      2008-02-24 22:00:00   VEHICLE THEFT
# 19     2013-03-08 08:00:00  OTHER OFFENSES
# ...                    ...             ...
# 24983  2011-07-29 08:00:00   LARCENY/THEFT
# 24985  2004-03-06 20:30:00       VANDALISM
# 24991  2004-11-08 22:00:00    NON-CRIMINAL
# 24992  2011-12-15 12:45:00   LARCENY/THEFT
# 24995  2005-05-04 22:30:00   VEHICLE THEFT
#
#                                         Descript  DayOfWeek PdDistrict  \
# 0                             ARSON OF A VEHICLE     Sunday    BAYVIEW
# 2                                  LOST PROPERTY   Saturday   SOUTHERN
# 4                        PETTY THEFT OF PROPERTY     Friday   NORTHERN
# 6                   STOLEN AND RECOVERED VEHICLE     Sunday  INGLESIDE
# 19                      TAMPERING WITH A VEHICLE     Friday   NORTHERN
# ...

# %%
# NO CODE HERE PLEASE
# Out:
#                      Dates        Category  \
# 0      2003-03-23 23:27:00           ARSON
# 2      2004-03-06 03:00:00    NON-CRIMINAL
# 4      2003-01-10 00:15:00   LARCENY/THEFT
# 6      2008-02-24 22:00:00   VEHICLE THEFT
# 19     2013-03-08 08:00:00  OTHER OFFENSES
# ...                    ...             ...
# 24983  2011-07-29 08:00:00   LARCENY/THEFT
# 24985  2004-03-06 20:30:00       VANDALISM
# 24991  2004-11-08 22:00:00    NON-CRIMINAL
# 24992  2011-12-15 12:45:00   LARCENY/THEFT
# 24995  2005-05-04 22:30:00   VEHICLE THEFT
#
#                                         Descript  DayOfWeek PdDistrict  \
# 0                             ARSON OF A VEHICLE     Sunday    BAYVIEW
# 2                                  LOST PROPERTY   Saturday   SOUTHERN
# 4                        PETTY THEFT OF PROPERTY     Friday   NORTHERN
# 6                   STOLEN AND RECOVERED VEHICLE     Sunday  INGLESIDE
# 19                      TAMPERING WITH A VEHICLE     Friday   NORTHERN
# ...
